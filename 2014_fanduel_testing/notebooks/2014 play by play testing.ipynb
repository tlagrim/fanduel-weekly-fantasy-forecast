# %% [markdown]
# #This data set consists of the 2014 season in a play by play format.
# 1 Row = 1 play.
# IMPORTANT NOTICE: This data set doesn't contain individual player's statistics.

# %%
# imports
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import pylab

# this allows plots to appear directly in the notebook
# %matplotlib inline
# increase size of plots
pylab.rcParams['figure.figsize'] = (15, 10)
# allow reading of all of the columns in a dataset
pd.options.display.max_columns = 50
pd.options.display.max_rows = 60

# %%
pbpData = pd.read_csv("../data/fanduel_data/nflsavant_data_sets/pbp-2014.csv")
pbpData.sort(['GameId'])

# remove column by index
dropCols = [10,12,16,17]
pbpData = pbpData.drop(pbpData.columns[dropCols],axis=1)

# %%
pbpData[pbpData['GameId'] == 2014090709 ]
# Out:
#           GameId    GameDate  Quarter  Minute  Second OffenseTeam DefenseTeam  \
# 0     2014090709  2014-09-07        2       1      57         NaN         MIN
# 1881  2014090709  2014-09-07        1      15       0         STL         MIN
# 1882  2014090709  2014-09-07        1      14      57         MIN         STL
# 1883  2014090709  2014-09-07        1      14      26         MIN         STL
# 1884  2014090709  2014-09-07        1      13      48         MIN         STL
# 1885  2014090709  2014-09-07        1      13       6         MIN         STL
# 1886  2014090709  2014-09-07        1      12      36         MIN         STL
# 1887  2014090709  2014-09-07        1      12       2         MIN         STL
# 1888  2014090709  2014-09-07        1      11      25         MIN         STL
# 1889  2014090709  2014-09-07        1      10      58         MIN         STL
# 1890  2014090709  2014-09-07        1      10      22         MIN         STL
# ...

# %%
pbpData
# Out:
#            GameId    GameDate  Quarter  Minute  Second OffenseTeam  \
# 0      2014090709  2014-09-07        2       1      57         NaN
# 1      2014090711  2014-09-07        4       0       0         NaN
# 2      2014090702  2014-09-07        4       4       2         BUF
# 3      2014090703  2014-09-07        2       0       4         NaN
# 4      2014091100  2014-09-11        4       0      31         BAL
# 5      2014091100  2014-09-11        4       0       0         NaN
# 6      2014091400  2014-09-14        3       0       0         NaN
# 7      2014091400  2014-09-14        3       0       0         NaN
# 8      2014091401  2014-09-14        3       0       0         NaN
# 9      2014091402  2014-09-14        2       8      55         ATL
# 10     2014090400  2014-09-04        1      15       0         SEA
# 11     2014090400  2014-09-04        1      14      56          GB
# 12     2014090400  2014-09-04        1      14      30          GB
# ...

# %% [markdown]
# ##Remove Unused columns
# NextScore, TeamWin, IsMeasurement

# %%
unusedCols = [11,13,27]
pbpData = pbpData.drop(pbpData.columns[unusedCols],axis=1)
pbpData.columns
# Out:
# Index(['GameId', 'GameDate', 'Quarter', 'Minute', 'Second', 'OffenseTeam', 'DefenseTeam', 'Down', 'ToGo', 'YardLine', 'SeriesFirstDown', 'Formation', 'IsRush', 'IsPass', 'IsIncomplete', 'IsTouchdown', 'PassType', 'IsSack', 'IsChallenge', 'IsChallengeReversed', 'Challenger', 'IsInterception', 'IsFumble', 'IsTwoPointConversion', 'IsTwoPointConversionSuccessful', 'YardLineFixed', 'YardLineDirection', 'IsPenaltyAccepted', 'PenaltyTeam', 'IsNoPlay', 'PenaltyType', 'PenaltyYards'], dtype='object')
